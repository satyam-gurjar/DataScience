# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X ,y = make_blobs(n_samples=500, n_features=5, centers=3, cluster_std=5,random_state=42)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.71576566,  0.7011966 , -0.09605437, -1.40210172, -1.17861095],
#        [ 0.3224436 ,  0.31233957, -0.09433292, -0.08784701, -0.61906054],
#        [-0.04759965, -0.16489162, -0.58352564, -0.50496041, -0.63791194],
#        ...,
#        [ 0.50794276, -0.70510632,  0.29772443,  0.7642776 ,  2.60664548],
#        [ 0.66966078,  0.84855091,  0.68946761, -0.1102979 , -0.8521288 ],
#        [-1.1044623 , -1.88513818,  0.86815479,  1.94299772,  0.88228326]])

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['label'] = y

# %%
df_pca
# Out:
#           PC1       PC2  label
# 0    1.700332 -1.128302      2
# 1    0.656013  0.302186      2
# 2    0.591091 -0.073000      0
# 3   -1.009711 -0.188032      1
# 4    0.602276 -0.802488      2
# ..        ...       ...    ...
# 495  0.252549  2.178416      0
# 496 -0.384292  0.428572      0
# 497 -2.456527  0.364714      1
# 498  1.007503  0.328744      0
# 499 -2.639708 -0.156782      1
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(data = df_pca, x = 'PC1', y = 'PC2', hue='label', palette='Set2')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>
